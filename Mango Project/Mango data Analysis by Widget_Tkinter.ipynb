# %%
from tkinter import *
import ipywidgets as widgets

def value1(n1):
    c=n1
    #Display_n1=Scale(window,label="Number 1 : ",orient="horizontal")
    #Display_n1.set(n1)
    #Display_n1.grid(row=1, column=0)
    return c
def value2(n2):
    c=n2
    #Display_n2=Scale(window,label="Number 2 : ",orient="horizontal")
    #Display_n2.set(n2)
    #Display_n2.grid(row=2, column=0)
    return c
'''def Sumvalue(n1,n2):
    Display_n1=Scale(window,label="Number 1 : ",orient="horizontal")
    Display_n1.set(n1)
    Display_n1.grid(row=1, column=0)
    
    sum=n1+n2
    c=sum 
    sumDisplay = Scale(window,label="Sum : ",orient="horizontal")
    sumDisplay.set(sum)
    sumDisplay.grid(row=3, column=0)
    #return c'''

window = Tk()
window.geometry("600x250")
w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Checkbox(value=True,Text="click me")


widgets.interact(value1,n1=w1)
widgets.interact(value2,n2=w2)
#widgets.interact(Sumvalue,n1=w1,n2=w2)
mainloop()

# %%
print("Hi")

# %%
## 1. Sum of two numbers using int sliders.
from tkinter import *
import ipywidgets as widgets
def SumOfValues(n1,n2):
    c=n1+n2
    s="Sum of "+str(n1)+" and "+str(n2)+" : "+str(c)
    print(s)
w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
widgets.interact(SumOfValues,n1=w1,n2=w2)

# %%
## 2. Displlay sum of two numbers using python widgets
from tkinter import *
import ipywidgets as widgets
def SumOfValues(n1,n2):
    c=n1+n2
    s="Sum of "+str(n1)+" and "+str(n2)+" : "+str(c)
    print(s)
    w3=widgets.IntText(description="SUM : ",value=c)
    display(w3)

w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
widgets.interact(SumOfValues,n1=w1,n2=w2)

# %%
## 3. Reading the csv data
import pandas as pd
location="C:\\Users\\dheeraj\\Desktop\\Python\\CHEM_DATA\\Mango data collection - Sheet1.csv"
'''
    print(num,' - ',batch_list.index(n),':',batch_list.index(n)+c)
    data=pd.read_csv(location,usecols=data.head())
    data=data.iloc[batch_list.index(n):batch_list.index(n)+c]
'''


data=pd.read_csv(location).rename(columns={'Unnamed: 15':'Overall remarks extended'})
#df=pd.read_csv(location,usecols=data.head()).rename(columns={'Unnamed: 15':'Overall remarks extended'})
'''def Full_data():
    return df'''
def Data_Location():
    return location
def Batch_Data():
    return data["Batch No."]
def Sample():
    return data["Sample"]
def Hard_A():
    return data["Hardness_A"]
def Hard_B():
    return data["Hardness_B"]
def PH_A1():
    return data["PH_A1"]
def PH_A2():
    return data["PH_A2"]
def BRIX_A1():
    return data["Brix_A1"]
def BRIX_A2():
    return data["Brix_A2"]
def BRIX_A3():
    return data["Brix_A3"]
def TA_A1():
    return data["TA_A1"]
def TA_A2():
    return data["TA_A2"]
def Moisture_B():
    return data["Moisture_B"]
def Carotenoid_B():
    return data["Carotenoids_B"]
def Carotenoid_Blank():
    return data["Carotenoids_Blank"]
def Remarks():
    return data["Overall remarks (defective or healthy)"]
def TA():
    return [data["TA_A1"],data["TA_A2"]]
def BRIX():
    return [data["Brix_A1"],data["Brix_A2"],data["Brix_A3"]]
def Hardness():
    return [data["Hardness_A"],data["Hardness_B"]]

# %%
## 3. Ploting after Reading the data from csv data
import matplotlib.pyplot as plt
import FromExcel
import pandas as pd
import numpy as np
from colorama import Fore
import tkinter
Data_column=[i for i in FromExcel.Full_data()]
while(1):
    print("-"*100)
    s=Fore.RED+"Press 0 for stopping execution"
    print(s)
    print(Fore.WHITE+"Press 1 for plotting fruit Batch ")
    print("Press 2 for plotting fruit Sample")
    print("Press 3 for plotting Hardness on A side")
    print("Press 4 for plotting hardness on B side")
    print("Press 5 for plotting PH on A side - 1st reading")
    print("Press 6 for plotting PH on A side - 2nd reading")
    print("Press 7 for plotting Brix on A side - 1st reading")
    print("Press 8 for plotting Brix on A side - 2nd reading")
    print("Press 9 for plotting Brix on A side - 3rd reading")
    print("Press 10 for plotting Tritable Acidity on A side - 1st reading")
    print("Press 11 for plotting Tritable Acidity on A side - 2nd reading") 
    print("Press 12 for plotting Moisture on B side")
    #print("Press 13 for plotting Carotenoids on B side")
    print("Press 13 for plotting Carotenoids_Blank")
    print("Press 14 for printing Remarks")
    print("Press 15 for plotting Acidity on A side")
    print("Press 16 for plotting Brix on A side")
    print("Press 17 for plotting Hardness on A and B side")
    print("Press 18 for printing any two data")
    Plot_Choice=int(input())
    if(Plot_Choice==0):
        break
    if(Plot_Choice==1):
        plt.figure(figsize=(18,10))
        plt.title("BATCH NUMBER")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis BATCH")
        #plt.plot(FromExcel.Batch_Data(),color='r')      # color="red"
        plt.bar(FromExcel.Sample(),FromExcel.Batch_Data(), color ='maroon',width = 0.4)
        print(FromExcel.Batch_Data())
        plt.show()

    elif(Plot_Choice==2):
        plt.figure(figsize=(18,10))
        plt.title("SAMPLE NUMBER")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis SAMPLE")
        #plt.plot(FromExcel.Sample(),color='g')     #color='green'
        plt.bar(FromExcel.Sample(), FromExcel.Sample(), color ='maroon',width = 0.4)
        print(FromExcel.Sample())
        plt.show()

    elif(Plot_Choice==3):
        plt.figure(figsize=(18,10))
        plt.title("HARDNESS ON A SIDE")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis A_HARDNESS")
        #plt.plot(FromExcel.Hard_A(),color='b')      #color='blue'
        plt.bar(FromExcel.Sample(), FromExcel.Hard_A(), color ='maroon',width = 0.4)
        print(FromExcel.Hard_A())
        plt.show()

    elif(Plot_Choice==4):
        plt.figure(figsize=(18,10))
        plt.title("HARDNESS ON B SIDE")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis B_HARDNESS")
        #plt.plot(FromExcel.Hard_B(),color='c')       #color='cyan'
        plt.bar(FromExcel.Sample(), FromExcel.Hard_B(), color ='maroon',width = 0.4)
        print(FromExcel.Hard_B())
        plt.show()

    elif(Plot_Choice==5):
        plt.figure(figsize=(18,10))
        plt.title("PH ON A SIDE_1")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis PH_A1")
        #plt.plot(FromExcel.PH_A1(),color='m')          #color='magneta'
        plt.bar(FromExcel.Sample(), FromExcel.PH_A1(), color ='maroon',width = 0.4)
        print(FromExcel.PH_A1())
        plt.show()

    elif(Plot_Choice==6):
        plt.figure(figsize=(18,10))
        plt.title("PH ON A SIDE_2")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis PH_A2")
        #plt.plot(FromExcel.PH_A2(),color='y')          #color='yellow'
        plt.bar(FromExcel.Sample(), FromExcel.PH_A2(), color ='maroon',width = 0.4)
        print(FromExcel.PH_A2())
        plt.show()

    elif(Plot_Choice==7):
        plt.figure(figsize=(18,10))
        plt.title("BRIX A SIDE_1")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis BRIX-A SIDE 1")
        #plt.plot(FromExcel.BRIX_A1(),color='k')   #color='black'
        plt.bar(FromExcel.Sample(), FromExcel.BRIX_A1(), color ='maroon',width = 0.4)
        print(FromExcel.BRIX_A1())
        plt.show()

    elif(Plot_Choice==8):
        plt.figure(figsize=(18,10))
        plt.title("BRIX A SIDE_2")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis BRIX-A SIDE 2")
        #plt.plot(FromExcel.BRIX_A2(),color='k')   #color='black'
        plt.bar(FromExcel.Sample(), FromExcel.BRIX_A2(), color ='maroon',width = 0.4)
        print(FromExcel.BRIX_A2())
        plt.show()

    elif(Plot_Choice==9):
        plt.figure(figsize=(18,10))
        plt.title("BRIX A SIDE_3")
        plt.xlabel("X-Axis FRUIT ID")
        #plt.ylabel("Y-Axis BRIX-A SIDE 3")9
        plt.bar(FromExcel.Sample(), FromExcel.BRIX_A3(), color ='maroon',width = 0.4)
        #plt.plot(FromExcel.BRIX_A3(),color='k')   #color='black'
        print(FromExcel.BRIX_A3())
        plt.show()

    elif(Plot_Choice==10):
        plt.figure(figsize=(18,10))
        plt.title("ACIDITY ON A SIDE_1")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis ACIDITY-A SIDE 1")
        #plt.plot(FromExcel.TA_A1(),color='k')   #color='black'
        plt.bar(FromExcel.Sample(), FromExcel.TA_A1(), color ='maroon',width = 0.4)
        print(FromExcel.TA_A1())
        plt.show()

    elif(Plot_Choice==11):
        plt.figure(figsize=(18,10))
        plt.title("ACIDITY ON A SIDE_2")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis ACIDITY-A SIDE 2")
        #plt.plot(FromExcel.TA_A2(),color='k')   #color='black'
        plt.bar(FromExcel.Sample(), FromExcel.TA_A2(), color ='maroon',width = 0.4)
        print(FromExcel.TA_A2())
        plt.show()

    elif(Plot_Choice==12):
        plt.figure(figsize=(18,10))
        plt.title("MOISTURE ON B SIDE")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis MOISTURE")
        #plt.plot(FromExcel.Moisture_B(),color='k')   #color='black'
        plt.bar(FromExcel.Sample(), FromExcel.Moisture_B(), color ='maroon',width = 0.4)
        print(FromExcel.Moisture_B())
        plt.show()
   
    elif(Plot_Choice==13):
        plt.figure(figsize=(18,10))
        plt.title("CAROTENOIDS BLANK")
        plt.xlabel("X-Axis FRUIT ID")
        plt.ylabel("Y-Axis CAROTENOIDS")
        plt.bar(FromExcel.Sample(), FromExcel.Carotenoid_Blank(), color ='maroon',width = 0.4)
        plt.show()
        
    elif(Plot_Choice==14):
        print(FromExcel.Remarks())
        
    elif(Plot_Choice==15):        
        fig,axis=plt.subplots(1,2,figsize=[18,10])
        fig.suptitle("ACIDITY A_1&2")
        SubData=FromExcel.TA()
        axis[0].set_title("ACIDITY SIDE_A1")
        axis[0].set_xlabel("X-Axis FRUIT ID")
        axis[0].set_ylabel("Y-Axis ACIDITY A1")
        axis[0].bar(FromExcel.Sample(), SubData[0], color ='r',width = 0.4)
        axis[1].set_title("ACIDITY SIDE_A2")
        axis[1].set_xlabel("X-Axis FRUIT ID")
        axis[1].set_ylabel("Y-Axis ACIDITY A2")
        axis[1].bar(FromExcel.Sample(), SubData[1], color ='g',width = 0.4)
        plt.show()

    elif(Plot_Choice==16):        
        fig,axis=plt.subplots(2,2,figsize=[18,10])
        fig.suptitle("BRIX A_1,2&3")
        SubData=FromExcel.BRIX()
        axis[0,0].set_title("BRIX SIDE_A1")
        axis[0,0].set_xlabel("X-Axis FRUIT ID")
        axis[0,0].set_ylabel("Y-Axis BRIX A1")
        axis[0,0].bar(FromExcel.Sample(), SubData[0], color ='red',width = 0.4)
        axis[0,1].set_title("BRIX SIDE_A2")
        axis[0,1].set_xlabel("X-Axis FRUIT ID")
        axis[0,1].set_ylabel("Y-Axis BRIX A2")
        axis[0,1].bar(FromExcel.Sample(), SubData[1], color ='green',width = 0.4)
        axis[1,0].set_title("BRIX SIDE_A3")
        axis[1,0].set_xlabel("X-Axis FRUIT ID")
        axis[1,0].set_ylabel("Y-Axis BRIX A3")
        axis[1,0].bar(FromExcel.Sample(), SubData[2], color ='blue',width = 0.4)

        axis[1,1].bar(FromExcel.Sample()+0.2,SubData[0], color ='red',width = 0.4,label="Brix A1")
        axis[1,1].bar(FromExcel.Sample(),SubData[1], color ='green',width = 0.4,label="Brix A2")
        axis[1,1].bar(FromExcel.Sample()-0.2,SubData[2], color ='blue',width = 0.4,label="Brix A3")
        axis[1,1].legend()
        plt.show()
    elif(Plot_Choice==17):
        fig,axis=plt.subplots(2,2,figsize=[18,10])
        fig.suptitle("HARDNESS A&B")
        SubData=FromExcel.Hardness()
        axis[0,0].set_title("HARDNESS SIDE_A")
        axis[0,0].set_xlabel("X-Axis FRUIT ID")
        axis[0,0].set_ylabel("Y-Axis HARDNESS A")
        axis[0,0].bar(FromExcel.Sample(), SubData[0], color ='red',width = 0.4)

        axis[0,1].set_title("HARDNESS SIDE_B")
        axis[0,1].set_xlabel("X-Axis FRUIT ID")
        axis[0,1].set_ylabel("Y-Axis HARDNESS B")
        axis[0,1].bar(FromExcel.Sample(), SubData[1], color ='green',width = 0.4)

        axis[1,0].set_title("HARDNESS SIDE_A&B linear")
        axis[1,0].set_xlabel("X-Axis FRUIT ID")
        axis[1,0].set_ylabel("Y-Axis HARDNESS A")
        axis[1,0].plot(FromExcel.Sample()+0.2, SubData[0], color ='red')
        axis[1,0].plot(FromExcel.Sample()-0.2, SubData[1], color ='green')
        
        axis[1,1].set_title("HARDNESS SIDE_A&B Bar")
        axis[1,1].set_xlabel("X-Axis FRUIT ID")
        axis[1,1].set_ylabel("Y-Axis HARDNESS A")
        axis[1,1].bar(FromExcel.Sample()+0.2, SubData[0], color ='red')
        axis[1,1].bar(FromExcel.Sample()-0.2, SubData[1], color ='green')
        #plt.plot(SubData[0],'o',color ='red')
        #plt.show(SubData[1],'o',color ='green')
        plt.show()

    elif(Plot_Choice==18):
        Data_choice1=int(input("Enetr choice 1 : "))
        Data_choice2=int(input("Enter chioce 2 : "))
        Data1=FromExcel.df[[Data_column[Data_choice1-1]]]
        Data2=FromExcel.df[Data_column[Data_choice2-1]]
        #print(len(Data1),'\t',len(Data2),'\t',len(FromExcel.Sample()))
        #print(Data1,'\n',Data2)
        plt.figure(figsize=(10,10))
        '''plt.title()
        plt.xlabel()
        plt.ylabel()'''
        plt.plot(FromExcel.Sample(),Data1,color='r')
        plt.plot(FromExcel.Sample(),Data2,color='g')
        #plt.xticks(FromExcel.Sample(),)
        plt.legend()
        plt.show()
        
    else:
        print("Invalid choice")
'''elif(Plot_Choice==13):
            plt.title("CAROTENOIDS")
            plt.xlabel("X-Axis FRUIT ID")
            plt.ylabel("Y-Axis CAROTENOIDS")
            #plt.plot(FromExcel.Sample(),FromExcel.Carotenoid_B(),color='k')   #color='black'
            plt.bar(FromExcel.Sample(), FromExcel.Carotenoid_B(), color ='maroon',width = 0.4)
            print(FromExcel.Carotenoid_B())
            plt.show()'''
'''
import numpy as np
import matplotlib.pyplot as plt

X = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys')

plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.title("Number of Students in each group")
plt.legend()
plt.show()

'''
# Out:
# ----------------------------------------------------------------------------------------------------
# Press 0 for stopping execution
# Press 1 for plotting fruit Batch
# Press 2 for plotting fruit Sample
# Press 3 for plotting Hardness on A side
# Press 4 for plotting hardness on B side
# Press 5 for plotting PH on A side - 1st reading
# Press 6 for plotting PH on A side - 2nd reading
# Press 7 for plotting Brix on A side - 1st reading
# Press 8 for plotting Brix on A side - 2nd reading
# Press 9 for plotting Brix on A side - 3rd reading
# Press 10 for plotting Tritable Acidity on A side - 1st reading
# Press 11 for plotting Tritable Acidity on A side - 2nd reading
# Press 12 for plotting Moisture on B side
# Press 13 for plotting Carotenoids_Blank
# Press 14 for printing Remarks
# Press 15 for plotting Acidity on A side
# Press 16 for plotting Brix on A side
# Press 17 for plotting Hardness on A and B side
# Press 18 for printing any two data
# 0      80.69
# 1      85.75
# ...

# %%
## 4. Extracting the data using intlider instead of giving the range manually
 
from tkinter import *
import ipywidgets as widgets
import pandas as pd
from colorama import Fore

location="C:\\Users\\dheeraj\\Desktop\\Python\\Sample_immature_mature.csv"

def SumOfValues(n1,n2):
    data=pd.read_csv(location)
    print("Total number of fruit samples : ",len(data))
    print("Starting index : ",n1)
    print("Last index : ",n2)
    print("Total number of data displayed : ",(n2-n1),"\n\n")
    df=pd.read_csv(location,usecols=data.head())
    batch=df
    batch_list=[]
    for i in batch:
        batch_list.append(i)
    data=data.iloc[n1:n2]
    if (n1<=n2):
        print(data)
    else:
        s=Fore.RED+"Starting index should be less than or equal to  last index"
        print(s)
        
data=pd.read_csv(location)
w1 = widgets.IntSlider(description="Index 1 : ",min=0,value=20,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="Index 2 : ",min=0,value=50,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Textarea(description="Location : ",value=input(),disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='s')
widgets.interact(SumOfValues,n1=w1,n2=w2)
# Out:
# interactive(children=(IntSlider(value=20, description='Index 1 : ', max=238), IntSlider(value=50, description=…
# <function __main__.SumOfValues(n1, n2)>

# %%
## 5. Extracting and plotting(line) the data for the range taken from intslider instead of giving the range manually

from tkinter import *
import ipywidgets as widgets
import pandas as pd
from colorama import Fore
import matplotlib.pyplot as plt

location="C:\\Users\\dheeraj\\Desktop\\Python\\Sample_immature_mature.csv"

def SumOfValues(n1,n2):
    data=pd.read_csv(location)
    print("Total number of fruit samples : ",len(data))
    print("Starting index : ",n1)
    print("Last index : ",n2)
    print("Total number of data displayed : ",(n2-n1),"\n")
    df=pd.read_csv(location,usecols=data.head())
    batch=df
    batch_list=[]
    for i in batch:
        batch_list.append(i)
    data=data.iloc[n1:n2]
    df=df.iloc[n1:n2]
    if (n1<=n2):
        #print(data)
        fig,axis=plt.subplots(2,2,figsize=[18,10])
        fig.suptitle("SPECTRO DATA OF BATCH : ")
        axis[0,0].set_title("DISTANCE TO PROBE")
        axis[0,0].set_xlabel("X-Axis FRUIT ID")
        axis[0,0].set_ylabel("Y-Axis DISTANCE")
        axis[0,0].plot(df["Distance"],color='k')   #color='black'

        axis[0,1].set_title("WEIGHT")
        axis[0,1].set_xlabel("X-Axis FRUIT ID")
        axis[0,1].set_ylabel("Y-Axis WEIGHT")
        axis[0,1].plot(df["WEIGHT_g"],color='y')          #color='yellow'

        axis[1,0].set_xlabel("X-Axis FRUIT ID")          
        axis[1,0].set_ylabel("Y-Axis VOLUME")  # 1. plotting length graph 
        axis[1,0].set_title("VOLUME")
        axis[1,0].plot(df["VOLUME_ml"],color='g')

        axis[1,1].set_title("SHORT , LONG , LENGTH")
        axis[1,1].set_xlabel("X-Axis FRUIT ID")          
        axis[1,1].set_ylabel("Y-Axis SHORT,LONG,LENGTH")  # 4. plotting short,long widths and length in graph 
        axis[1,1].plot(df["LABEL"],df["DIA1_mm_shortwidth"],color='b',label="Short Width")
        axis[1,1].plot(df["LABEL"],df["DIA2_mm_longwidth"],color='c',label="Long Width")
        axis[1,1].plot(df["LABEL"],df["DIA3_mm_length"],color='m',label="Length")
        axis[1,1].legend()
        
    else:
        print("Starting index should be less than or equal to  last index")
        
data=pd.read_csv(location)
w1 = widgets.IntSlider(description="Index 1 : ",min=0,value=20,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="Index 2 : ",min=0,value=50,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Textarea(description="Location : ",value=location,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='s')
widgets.interact(SumOfValues,n1=w1,n2=w2)

# %%
## 6. Extracting and plotting(bar) the data for the range taken from intslider instead of giving the range manually

from tkinter import *
import ipywidgets as widgets
import pandas as pd
from colorama import Fore
import matplotlib.pyplot as plt

location="C:\\Users\\dheeraj\\Desktop\\Python\\Sample_immature_mature.csv"

def SumOfValues(n1,n2):
    data=pd.read_csv(location)
    print("Total number of fruit samples : ",len(data))
    print("Starting index : ",n1)
    print("Last index : ",n2)
    print("Total number of data displayed : ",(n2-n1),"\n")
    df=pd.read_csv(location,usecols=data.head())
    batch=df
    batch_list=[]
    for i in batch:
        batch_list.append(i)
    data=data.iloc[n1:n2]
    df=df.iloc[n1:n2]
    if (n1<=n2):
        #print(data)
        fig,axis=plt.subplots(2,2,figsize=[18,10])
        fig.suptitle("SPECTRO DATA OF BATCH : ")
        axis[0,0].set_title("DISTANCE TO PROBE")
        axis[0,0].set_xlabel("X-Axis FRUIT ID")
        axis[0,0].set_ylabel("Y-Axis DISTANCE")
        axis[0,0].bar(df["LABEL"],df["Distance"],color='k')   #color='black'

        axis[0,1].set_title("WEIGHT")
        axis[0,1].set_xlabel("X-Axis FRUIT ID")
        axis[0,1].set_ylabel("Y-Axis WEIGHT")
        axis[0,1].bar(df["LABEL"],df["WEIGHT_g"],color='y')          #color='yellow'

        axis[1,0].set_xlabel("X-Axis FRUIT ID")          
        axis[1,0].set_ylabel("Y-Axis VOLUME")  # 1. plotting length graph 
        axis[1,0].set_title("VOLUME")
        axis[1,0].bar(df["LABEL"],df["VOLUME_ml"],color='g')

        axis[1,1].set_title("SHORT , LONG , LENGTH")
        axis[1,1].set_xlabel("X-Axis FRUIT ID")          
        axis[1,1].set_ylabel("Y-Axis SHORT,LONG,LENGTH")  # 4. plotting short,long widths and length in graph 
        axis[1,1].bar(df["LABEL"]+0.2,df["DIA1_mm_shortwidth"],color='b',label="Short Width",width=0.1)
        axis[1,1].bar(df["LABEL"],df["DIA2_mm_longwidth"],color='c',label="Long Width",width=0.1)
        axis[1,1].bar(df["LABEL"]-0.2,df["DIA3_mm_length"],color='m',label="Length",width=0.1)
        axis[1,1].legend()
        
        '''
        

        
        '''
    else:
        print("Starting index should be less than or equal to  last index")
        
data=pd.read_csv(location)
w1 = widgets.IntSlider(description="Index 1 : ",min=0,value=20,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="Index 2 : ",min=0,value=50,max=len(data),step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Textarea(description="Location : ",value=location,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='s')
widgets.interact(SumOfValues,n1=w1,n2=w2)
# Out:
# interactive(children=(IntSlider(value=20, description='Index 1 : ', max=238), IntSlider(value=50, description=…
# <function __main__.SumOfValues(n1, n2)>

# %%
import pandas as pd
#https://docs.google.com/spreadsheets/d/19funGD8yIAmRV3wrTsUIAPazyMtOHr1l/
Sheetcode="19funGD8yIAmRV3wrTsUIAPazyMtOHr1l"
df=pd.read_csv(f"https://docs.google.com/spreadsheets/d/{Sheetcode}/export?format=csv")
#df=df.head()
print(len(df["Date of acquisition"]))
# Out:
# 348

# %%
#print(df)
print(df["Date of acquisition"])
# Out:
# 0      01-04-2023
# 1      01-04-2023
# 2      01-04-2023
# 3      01-04-2023
# 4      01-04-2023
#           ...
# 343    21-06-2023
# 344    21-06-2023
# 345    21-06-2023
# 346    21-06-2023
# 347    21-06-2023
# Name: Date of acquisition, Length: 348, dtype: object

# %%
from tkinter import *
import ipywidgets as widgets


def Sumvalue(n1,n2):
    Display_n1=Scale(window,label="Number 1 : ",orient="horizontal")
    Display_n1.set(n1)
    Display_n1.grid(row=1, column=0)
    Display_n2=Scale(window,label="Number 2 : ",orient="horizontal")
    Display_n2.set(n2)
    Display_n2.grid(row=2, column=0)
    sum=n1+n2
    sumDisplay = Scale(window,label="Sum : ",orient="horizontal")
    sumDisplay.set(sum)
    sumDisplay.grid(row=3, column=0)
    #return c
def clickok(b):
    okButton=Button(window,b,text="OK")
    okButton.grid(row=2,column=1)
    display(okButton)

window = Tk()
window.geometry("600x250")
w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w4 = widgets.Checkbox(value=True,Text="click me")

widgets.interact(Sumvalue,n1=w1,n2=w2)
mainloop()
# Out:
# interactive(children=(IntSlider(value=20, description='W1 : '), IntSlider(value=50, description='W2 : '), Outp…

# %%
'''import ipywidgets as widgets
from IPython.display import display
from tkinter import *
from tkinter.ttk import *

def value1(n):
    c=n
    return c
def value2(n):
    c=n
    return c
def process_name():
    global name_entry,nameLabel
    print("Hi {}".format(name_entry.get()))   # Output on terminal.
    nameLabel.configure(text=f'Hi {name_entry.get()}')          # Output display text
    print(Widget1.get())
def show_values():
    print (Widget1.get())


def value3(n):
    display(n)
    global name_entry, nameLabel, nameLabel2, Widget1
    window = Tk()                                                 # window
    window.geometry("600x250")                                    # window size
    
    name_label = Label(window, text='Enter name a name below:')   # Addding a label text
    name_label.grid(row=0, column=0)                              # label position in window
    
    name_entry = Entry(window)                                    # Input text for added label with label text
    name_entry.grid(row=1, column=0)                              # label position in window
    
    button = Button(window, text='OK',command=process_name, padding=10)
    button.grid(row=1, column=2, columnspan=1)    # I defined a label BELOW the button to show how to change
    
    nameLabel2 = Label(window, text='Entered name : ')
    nameLabel2.grid(row=1,column=3)

    nameLabel = Label(window, text='')
    nameLabel.grid(row=1,column=4)

    #Widget1 = Scale(window, from_=0, to=42)
    Widget1 = Scale(window, from_=0, to=42)
    Widget1.set(20)
    Widget1.grid(row=3,column=0)
    Widget1.set(19)
    #Widget1.pack()      
    window.mainloop()


w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Checkbox(value=True,Text="click me")
widgets.interact(value1,n=w1)
widgets.interact(value2,n=w2)
widgets.interact(value3,n=w3)	'''


import ipywidgets as widgets
from IPython.display import display
from tkinter import *
from tkinter.ttk import *

def process_name():
    global name_entry,nameLabel
    print("Hi {}".format(name_entry.get()))   # Output on terminal.
    nameLabel.configure(text=f'Hi {name_entry.get()}')          # Output display text
    print(Widget1.get())

'''def value1(n):
    c=n
    return c
def value2(n):
    c=n
    return c'''
def value3(n):
    display(n)
    window = Tk()                                                 # window
    window.geometry("600x250")                                    # window size
    
    name_label = Label(window, text='Enter name a name below:')   # Addding a label text
    name_label.grid(row=0, column=0) 
    name_entry = Entry(window)                                    # Input text for added label with label text
    name_entry.grid(row=1, column=0)
    button = Button(window, text='OK',command=process_name, padding=10)
    button.grid(row=1, column=2, columnspan=1)    # I defined a label BELOW the button to show how to change
    
    nameLabel2 = Label(window, text='Entered name : ')
    nameLabel2.grid(row=1,column=3)

    nameLabel = Label(window, text='')
    nameLabel.grid(row=1,column=4)


window = Tk()
Widget1 = Scale(window, from_=0, to=42)
Widget1.set(19)

w1 = widgets.IntSlider(description="W1 : ",min=0,value=20,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w2 = widgets.IntSlider(description="W2 : ",min=0,value=50,max=100,step=1,disabled=False,contionous_update=False,orientation='horizontal',readout=True,readout_format='d')
w3 = widgets.Checkbox(value=True,Text="click me")
#widgets.interact(value1,n=w1)
#widgets.interact(value2,n=w2)
widgets.interact(value3,n=w3)

# %%
import tkinter as tk

root = tk.Tk()
root.title("Tkinter World")

label = tk.Label(root, text="Hello, Studytonight!")
label.pack()

entry = tk.Entry(root)
entry.pack()

button = tk.Button(root, text="Click Me!")
button.pack()

root.mainloop()

# %%
from tkinter import *
def show_values():
    print (Widget1.get())
window = Tk()
Widget1 = Scale(window, from_=0, to=42, tickinterval=8)
Widget1.set(19)
Widget1.pack()
mainloop()

# %%
'''root = Tk()
frame = Frame(root)
frame.pack()
button = Button(frame, text ='Geek')
button.pack()
import ipywidgets as widgets
from IPython.display import display
w = widgets.IntSlider()
display(w)'''

'''from tkinter import *    
top = Tk()    
top.geometry("400x250")  

uname = Label(top, text = "Username").place(x = 30,y = 50)    
password = Label(top, text = "Password").place(x = 30, y = 90)   
  
# Text Field
e1 = Entry(top,text = "Username",width = 20).place(x = 100, y = 50)  
e2 = Entry(top,text = "pwd", width = 20).place(x = 100, y = 90) 
sbmitbtn = Button(top, text = "Submit",activebackground = "pink", activeforeground = "blue").place(x = 30, y = 120) 

e3 = Text(top,text = e2, width = 20).place(x = 100, y = 150)
top.mainloop()'''


from tkinter import *
from tkinter.ttk import *
import ipywidgets as widgets
def process_name():
    global name_entry , out
    print("Hi {}".format(name_entry.get()))   # Output on terminal.
    global nameLabel 
    nameLabel.configure(text=f'Hi {name_entry.get()}')          # Output display text

def main():
    global name_entry, nameLabel, nameLabel2,label
    window = Tk()                                                 # window
    window.geometry("600x250")                                    # window size
    
    name_label = Label(window, text='Enter name a name below:')   # Addding a label text
    name_label.grid(row=0, column=0)                              # label position in window
    
    name_entry = Entry(window)                                    # Input text for added label with label text
    name_entry.grid(row=1, column=0)                              # label position in window
    
    button = Button(window, text='Say hello', command=process_name, padding=10)
    button.grid(row=1, column=2, columnspan=1)    # I defined a label BELOW the button to show how to change
    
    nameLabel2 = Label(window, text='Entered name : ')
    nameLabel2.grid(row=1,column=3)

    nameLabel = Label(window, text='')
    nameLabel.grid(row=1,column=4)

    #window.mainloop()
main()
