# %% [markdown]
# # Task 1

# %%
'''
Imported OS module to access folders, directory informations
'''
import os                       # Import os module(operating systems) for accessing files
parent_path=os.getcwd()         # To get current working directory
folder_names=os.listdir()       # To get all directory or file name in current working directory
print(parent_path)              # Display current working directory path
print(folder_names)             # Display all working directory or file name in current working directory
# Out:
# c:\Users\KIIT\Desktop\CDAC Tasks
# ['Datascience_Assessment_Details.docx.pdf', 'Task 1 Data', 'Task 2 Data', 'Task_1.ipynb', 'Task_2.ipynb']

# %%
'''
To get or access specific folder or directory information
'''
Task_1_Datasetpath=parent_path+"\\"+"Task 1 Data"   # To store a speciic path in a reerence variable
dataset_task1=os.listdir(Task_1_Datasetpath)        # To access specific folder path
print(dataset_task1)                                # To get all file names in a specific folder path
# Out:
# ['Test1_1.csv', 'Test1_2.csv', 'Test1_3.csv']

# %%
'''
importing pandas module for file operations and handling data frame
'''
import pandas as pd                                         # Importing pandas module
data_1=pd.read_csv(Task_1_Datasetpath+"\\"+'Test1_1.csv')   # Using pandas reading the .csv file named "Test1_1.csv"
data_2=pd.read_csv(Task_1_Datasetpath+"\\"+'Test1_2.csv')   # Using pandas reading the .csv file named "Test1_2.csv"
data_3=pd.read_csv(Task_1_Datasetpath+"\\"+'Test1_3.csv')   # Using pandas reading the .csv file named "Test1_3.csv"
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_2912\3517385443.py:7: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_3=pd.read_csv(Task_1_Datasetpath+"\\"+'Test1_3.csv')   # Using pandas reading the .csv file named "Test1_3.csv"

# %%
'''
Displaying data from Test1_1.csv data set file
'''
data_1.head()   # Displaying first five rows of data from "Test1_1.csv" file
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
'''
Displaying data from Test1_2.csv data set file
'''
data_2.head()   # Displaying first five rows of data from "Test1_2.csv" file
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
'''
Displaying data from Test1_3.csv data set file
'''
data_3.head()   # Displaying first five rows of data from "Test1_3.csv" file
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
print(data_1.shape)    # To check number of rows and columns of data_1 (Test1_1.csv)
print(data_1.ndim)     # To check dimensionality of data_1 (Test1_1.csv)
# Out:
# (14, 2)
# 2

# %%
data_1.isnull().sum()       # To count number of null values in a data set "Test1_1.csv" file
# Out:
# IATA_CODE    0
# AIRLINE      0
# dtype: int64

# %%
data_1.info()       # To get information about each column about dataframe , "Test1_1.csv" file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  14 non-null     object
#  1   AIRLINE    14 non-null     object
# dtypes: object(2)
# memory usage: 356.0+ bytes

# %%
data_1.describe()   # To get description about dataframe , "Test1_1.csv" file
# Out:
#        IATA_CODE                AIRLINE
# count         14                     14
# unique        14                     14
# top           UA  United Air Lines Inc.
# freq           1                      1

# %%
print(data_2.shape)    # To check number of rows and columns of data_2 (Test1_2.csv)
print(data_2.ndim)     # To check dimensionality of data_2 (Test1_2.csv)
# Out:
# (322, 7)
# 2

# %%
data_2.isnull().sum()       # To count number of null values in a (Data frame)data set "Test1_2.csv" file
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     3
# LONGITUDE    3
# dtype: int64

# %%
'''
Null values found in data set in "Test1_2.csv" file. Dropping the null values.
'''
data_2.dropna(inplace=True) # Dropping null values and saving the changes permanently
data_2.isnull().sum()       # To count number of null values in a (Data frame)data set "Test1_2.csv" file
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     0
# LONGITUDE    0
# dtype: int64

# %%
data_2.info()       # To get information about each column about dataframe , "Test1_2.csv" file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  319 non-null    object
#  1   AIRPORT    319 non-null    object
#  2   CITY       319 non-null    object
#  3   STATE      319 non-null    object
#  4   COUNTRY    319 non-null    object
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 19.9+ KB

# %%
data_2.describe()   # To get description about dataframe , "Test1_2.csv" file
# Out:
#          LATITUDE   LONGITUDE
# count  319.000000  319.000000
# mean    38.981244  -98.378964
# std      8.616736   21.523492
# min     13.483450 -176.646030
# 25%     33.652040 -110.839385
# 50%     39.297610  -93.403070
# 75%     43.154675  -82.722995
# max     71.285450  -64.798560

# %%
print(data_3.shape)    # To check number of rows and columns of data_3 (Test1_3.csv)
print(data_3.ndim)     # To check dimensionality of data_3 (Test1_3.csv)
# Out:
# (5819079, 31)
# 2

# %%
data_3.iloc[:,:].isnull().sum()       # To count number of null values in a (Data frame)data set "Test1_3.csv" file before handling data
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %%
data_3.info()   # To get information about each column about dataframe , "Test1_3.csv" file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
'''
Filling null values in "TAIL_NUMBER" column with default value
'''
print(data_3["TAIL_NUMBER"].unique())                                                   # Checking for unique values
print("Count before handling null values : ",data_3["TAIL_NUMBER"].isnull().sum())      # Checking number of null values before handling null values
data_3["TAIL_NUMBER"].fillna("",inplace=True)                                           # Filling null values with default values
print("Count after handling null values : ",data_3["TAIL_NUMBER"].isnull().sum())       # Checking number of null values after handling null values
# Out:
# ['N407AS' 'N3KUAA' 'N171US' ... 'N7LEAA' 'N850DN' 'N8676A']
# Count before handling null values :  14721
# Count after handling null values :  0

# %%
'''
Filling null values in "DEPARTURE_TIME" column with default value
'''
print(data_3["DEPARTURE_TIME"].unique())                                                    # Checking for unique values
print("Count before handling null values : ",data_3["DEPARTURE_TIME"].isnull().sum())       # Checking number of null values before handling null values
data_3["DEPARTURE_TIME"].fillna("",inplace=True)                                            # Filling null values with default values
print("Count after handling null values : ",data_3["DEPARTURE_TIME"].isnull().sum())        # Checking number of null values after handling null values
# Out:
# [2.354e+03 2.000e+00 1.800e+01 ... 3.460e+02 4.030e+02 3.540e+02]
# Count before handling null values :  86153
# Count after handling null values :  0

# %%
'''
Filling null values in "DEPARTURE_DELAY" column with median value
'''
print(data_3["DEPARTURE_DELAY"].unique())                                                   # Checking for unique values
print("Count before handling null values : ",data_3["DEPARTURE_DELAY"].isnull().sum())      # Checking number of null values before handling null values
data_3["DEPARTURE_DELAY"].fillna(data_3["DEPARTURE_DELAY"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["DEPARTURE_DELAY"].isnull().sum())       # Checking number of null values after handling null values
# Out:
# [ -11.   -8.   -2. ...  888. 1194. 1649.]
# Count before handling null values :  86153
# Count after handling null values :  0

# %%
'''
Filling null values in "TAXI_OUT" column with median value
'''
print(data_3["TAXI_OUT"].unique())                                              # Checking for unique values
print("Count before handling null values : ",data_3["TAXI_OUT"].isnull().sum()) # Checking number of null values before handling null values
data_3["TAXI_OUT"].fillna(data_3["TAXI_OUT"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["TAXI_OUT"].isnull().sum())  # Checking number of null values after handling null values
# Out:
# [ 21.  12.  16.  15.  11.  18.  13.  17.  28.  25.   9.  30.  14.  10.
#   nan  43.  24.  19.  22.  23.  37.  31.   7.  32.  26.  33.  42.  27.
#   20.  38.   4.  29.   8.  41.  56.  48.  40.  34.   3.  36.  61.  35.
#    6.  45.  39.  46.  62.  49.   5.  57.  64.  63.  47.  54.  55.  44.
#   59.  50.  76. 113.  73.  58.  52.   2.  72.  51. 110.  53.  75.  84.
#   77.  82.  70. 105.  69.  71.  81.  66.  80.  99.  60.  74.  95.  89.
#  136. 131.  79.  68. 120.  67.  88.   1.  65. 176. 160. 104. 111. 112.
#   83.  85. 121. 100.  91.  97.  93.  87. 129.  92.  90.  98. 107. 124.
#  146.  86.  78. 115. 103.  94. 101. 102. 126. 116. 132. 118. 106. 130.
#  109. 114. 128.  96. 141. 125. 149. 147. 122. 117. 108. 119. 137. 133.
#  135. 169. 152. 139. 143. 155. 153. 127. 150. 134. 145. 170. 140. 138.
#  151. 159. 168. 177. 123. 167. 156. 144. 162. 164. 171. 142. 154. 174.
#  161. 165. 148. 178. 179. 175. 166. 185. 181. 225. 180. 158. 200. 157.
#  173. 172. 163.]
# ...

# %%
'''
Filling null values in "WHEELS_OFF" column with median value
'''
print(data_3["WHEELS_OFF"].unique())                                                # Checking for unique values
print("Count before handling null values : ",data_3["WHEELS_OFF"].isnull().sum())   # Checking number of null values before handling null values
data_3["WHEELS_OFF"].fillna(data_3["WHEELS_OFF"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["WHEELS_OFF"].isnull().sum())    # Checking number of null values after handling null values
# Out:
# [ 15.  14.  34. ... 356. 346. 407.]
# Count before handling null values :  89047
# Count after handling null values :  0

# %%
'''
Filling null values in "SCHEDULED_TIME" column with median value
'''
print(data_3["SCHEDULED_TIME"].unique())                                                    # Checking for unique values
print("Count before handling null values : ",data_3["SCHEDULED_TIME"].isnull().sum())       # Checking number of null values before handling null values
data_3["SCHEDULED_TIME"].fillna(data_3["SCHEDULED_TIME"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["SCHEDULED_TIME"].isnull().sum())        # Checking number of null values after handling null values
# Out:
# [205. 280. 286. 285. 235. 217. 181. 273. 195. 221. 173. 268. 214. 215.
#  189. 204. 210. 218. 193. 162. 338. 147. 183. 213. 207. 245. 227. 239.
#  170. 370. 323. 255. 208. 123. 120. 184. 246. 224. 200. 185. 240. 174.
#  186. 241. 228.  70.  49.  89.  42.  36. 175.  63. 140.  68.  69.  87.
#  165. 161. 178. 150. 141. 103.  74.  66. 112.  60.  37.  65.  95. 230.
#  142. 157. 125.  55. 160. 188.  90. 163. 146. 167.  88.  85. 225.  61.
#   75. 212. 101. 136. 223. 122. 143. 105. 137. 104. 145. 139. 251. 209.
#   77. 124. 116. 129. 190. 154.  96. 314. 194. 119. 180.  59. 149. 135.
#  249. 166. 131. 341. 156. 275.  83.  50.  94.  80. 192. 148.  97. 110.
#  115. 130. 270. 100. 257. 244. 404. 311. 250. 281. 114. 164. 155. 109.
#  234.  73. 102. 151. 171. 168. 203. 232. 128.  84. 118. 159. 127. 317.
#  304. 113. 191. 233.  82.  99. 242. 107. 126. 158.  79.  92. 134.  76.
#  260. 153.  78. 117. 238.  98.  58.  52.  64.  51.  93.  72.  46. 132.
# ...

# %%
'''
Filling null values in "ELAPSED_TIME" column with median value 
'''
print(data_3["ELAPSED_TIME"].unique())                                                  # Checking for unique values
print("Count before handling null values : ",data_3["ELAPSED_TIME"].isnull().sum())     # Checking number of null values before handling null values
data_3["ELAPSED_TIME"].fillna(data_3["ELAPSED_TIME"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["ELAPSED_TIME"].isnull().sum())      # Checking number of null values after handling null values
# Out:
# [194. 279. 293. 281. 215. 230. 170. 249. 193. 203. 149. 266. 210. 199.
#  198. 200. 217. 201. 186. 143. 347. 147. 276. 163. 175. 218. 220. 224.
#  208. 234.  nan 231. 385. 322. 241. 248. 191. 125. 209. 178. 264. 183.
#  247. 196. 243. 258. 232.  74.  51.  85.  48.  36. 182.  55. 134.  78.
#   67. 168. 155. 189. 150. 137. 106.  72.  57. 110.  35.  70. 142. 157.
#  138.  44. 146. 167. 180. 153.  52.  75.  80. 164.  84. 114. 101. 103.
#  132. 188. 113. 144. 136. 197.  59. 190.  66. 202. 104. 122. 128. 133.
#   99. 282. 109. 179.  61. 172.  76. 223. 177. 343. 251. 269.  73.  50.
#   83.  93.  90. 160. 120. 152.  79. 131. 130. 135.  88. 145.  81. 270.
#  256. 141. 242. 165. 396. 291. 227. 173. 294. 174. 181. 151. 127. 102.
#   68. 226. 156. 222. 124. 108.  94. 166. 162. 239. 246. 139. 118. 212.
#  126. 280. 300.  91. 171.  92. 274.  97. 119.  95.  63. 262. 148. 115.
#   53.  96. 112. 158.  58. 237.  65. 121.  77.  39.  86. 317. 378. 287.
# ...

# %%
'''
Filling null values in "AIR_TIME" column with median value
'''
print(data_3["AIR_TIME"].unique())                                              # Checking for unique values
print("Count before handling null values : ",data_3["AIR_TIME"].isnull().sum()) # Checking number of null values before handling null values
data_3["AIR_TIME"].fillna(data_3["AIR_TIME"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["AIR_TIME"].isnull().sum())  # Checking number of null values after handling null values
# Out:
# [169. 263. 266. 258. 199. 206. 154. 228. 173. 186. 133. 238. 188. 176.
#  166. 171. 187. 128. 311. 255. 150. 156. 205. 217.  nan 182. 148. 361.
#  298. 220. 170. 231. 174. 103. 149. 239. 183. 225. 160. 224. 163. 237.
#  214.  39.  35.  61.  30. 179.  20. 147.  38. 112.  41. 146. 132. 111.
#   66.  49.  42.  79.  34.  21. 210. 125. 138.  96.  22. 143. 127. 142.
#  194.  56.  50. 184.  33.  54. 129.  95. 178.  84. 105. 109. 158.  72.
#   36. 107. 152.  44. 180.  86.  91. 120. 104. 134.  27.  78. 234. 118.
#   46. 159.  28. 110.  58. 195. 198. 130. 162. 310. 131. 216. 243.  43.
#   48.  25.  65.  92. 123. 100. 135.  57.  90.  88. 114. 175.  63. 230.
#   76. 253. 222. 126.  52. 376. 268. 201. 155. 273.  87. 137. 124. 106.
#   80. 151. 139. 190.  82. 202.  99. 141.  60. 145. 157. 140.  62. 117.
#   97.  68. 280.  75. 213. 144.  85. 196.  45.  69. 248. 153.  98.  51.
#   37.  47. 209.  64.  73.  67. 108. 119.  89.  24. 115.  55. 292. 355.
# ...

# %%
'''
Filling null values in "WHEELS_ON" column with median value
'''
print(data_3["WHEELS_ON"].unique())                                             # Checking for unique values
print("Count before handling null values : ",data_3["WHEELS_ON"].isnull().sum())# Checking number of null values before handling null values
data_3["WHEELS_ON"].fillna(data_3["WHEELS_ON"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["WHEELS_ON"].isnull().sum()) # Checking number of null values after handling null values
# Out:
# [404. 737. 800. ... 318. 324. 322.]
# Count before handling null values :  92513
# Count after handling null values :  0

# %%
'''
Filling null values in "TAXI_IN" column with median value
'''
print(data_3["TAXI_IN"].unique())                                               # Checking for unique values
print("Count before handling null values : ",data_3["TAXI_IN"].isnull().sum())  # Checking number of null values before handling null values
data_3["TAXI_IN"].fillna(data_3["TAXI_IN"].dropna().median(),inplace=True)      # Filling null values with default median value
print("Count after handling null values : ",data_3["TAXI_IN"].isnull().sum())   # Checking number of null values after handling null values
# Out:
# [  4.  11.   8.   5.   6.   3.   7.   2.  40.  10.  nan  12.   9.  13.
#   19.  14.  15.  30.  17.  16.  23.  52.  21.  26.  80.  29.  24.  20.
#   22.  18.  32.  55.  33.  34.   1.  27.  28.  25.  36.  41.  39.  37.
#   61.  74.  58.  31.  46.  42.  44.  35.  43.  45.  56.  48.  38.  53.
#   59.  50.  49.  67.  47.  70.  51.  84.  62.  54.  60. 103.  63.  66.
#   82.  57.  91.  72.  64.  69. 111.  65.  78.  68.  79.  95.  88.  89.
#   71.  90.  77.  76.  73.  87.  75.  93.  83.  81.  96. 105.  92.  86.
#   97. 122. 146. 123. 127. 138. 124. 136. 100. 134. 109. 101. 112. 133.
#  142. 117. 115. 170. 120. 149. 179. 128. 135.  85. 137. 108. 174. 141.
#  158. 145. 167. 106. 113. 107.  99. 154. 126. 125.  98. 104. 114. 144.
#  102. 162. 151. 140. 119. 148. 143.  94. 152. 130. 132. 157. 129. 121.
#  139. 110. 197. 147. 131. 163. 116. 118. 180. 153. 177. 173. 184. 160.
#  202. 178. 175. 150. 155. 176. 164. 166. 156. 181. 183. 168. 169. 172.
#  161. 171. 165. 248.]
# ...

# %%
'''
Filling null values in "ARRIVAL_TIME" column with median value
'''
print(data_3["ARRIVAL_TIME"].unique())                                                  # Checking for unique values
print("Count before handling null values : ",data_3["ARRIVAL_TIME"].isnull().sum())     # Checking number of null values before handling null values
data_3["ARRIVAL_TIME"].fillna(data_3["ARRIVAL_TIME"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["ARRIVAL_TIME"].isnull().sum())      # Checking number of null values after handling null values
# Out:
# [408. 741. 811. ... 328. 317. 357.]
# Count before handling null values :  92513
# Count after handling null values :  0

# %%
'''
Filling null values in "ARRIVAL_DELAY" column with median value
'''
print(data_3["ARRIVAL_DELAY"].unique())                                                 # Checking for unique values
print("Count before handling null values : ",data_3["ARRIVAL_DELAY"].isnull().sum())    # Checking number of null values before handling null values
data_3["ARRIVAL_DELAY"].fillna(data_3["ARRIVAL_DELAY"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["ARRIVAL_DELAY"].isnull().sum())     # Checking number of null values after handling null values
# Out:
# [ -22.   -9.    5. ... 1115. 1372. 1076.]
# Count before handling null values :  105071
# Count after handling null values :  0

# %%
'''
Filling null values in "CANCELLATION_REASON" column with median value 
'''
print(data_3["CANCELLATION_REASON"].unique())                                               # Checking for unique values
print("Count before handling null values : ",data_3["CANCELLATION_REASON"].isnull().sum())  # Checking number of null values before handling null values
data_3["CANCELLATION_REASON"].fillna("",inplace=True)                                       # Filling null values with default median value
print("Count after handling null values : ",data_3["CANCELLATION_REASON"].isnull().sum())   # Checking number of null values after handling null values
# Out:
# [nan 'A' 'B' 'C' 'D']
# Count before handling null values :  5729195
# Count after handling null values :  0

# %%
'''
Filling null values in "AIR_SYSTEM_DELAY" column with median value
'''
print(data_3["AIR_SYSTEM_DELAY"].unique())                                                      # Checking for unique values
print("Count before handling null values : ",data_3["AIR_SYSTEM_DELAY"].isnull().sum())         # Checking number of null values before handling null values
data_3["AIR_SYSTEM_DELAY"].fillna(data_3["AIR_SYSTEM_DELAY"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["AIR_SYSTEM_DELAY"].isnull().sum())          # Checking number of null values after handling null values
# Out:
# [      nan 2.500e+01 4.300e+01 0.000e+00 2.000e+01 1.700e+01 1.300e+01
#  7.000e+00 2.200e+01 1.400e+01 4.000e+00 6.000e+00 1.600e+01 2.700e+01
#  1.200e+01 2.000e+00 1.500e+01 1.800e+01 3.200e+01 8.500e+01 3.000e+00
#  5.000e+00 8.600e+01 5.800e+01 3.500e+01 3.400e+01 3.300e+01 1.100e+01
#  9.000e+00 2.600e+01 2.800e+01 4.000e+01 2.300e+01 1.900e+01 2.400e+01
#  9.700e+01 2.900e+01 2.100e+01 1.000e+00 1.000e+01 8.000e+00 3.000e+01
#  6.700e+01 4.800e+01 6.500e+01 3.100e+01 4.100e+01 4.200e+01 3.900e+01
#  3.600e+01 5.100e+01 8.100e+01 4.600e+01 1.640e+02 5.200e+01 8.800e+01
#  4.900e+01 4.500e+01 3.700e+01 5.000e+01 5.400e+01 5.900e+01 1.380e+02
#  5.300e+01 7.200e+01 6.800e+01 7.700e+01 6.100e+01 6.000e+01 4.400e+01
#  3.800e+01 7.600e+01 4.700e+01 7.300e+01 5.700e+01 7.400e+01 8.700e+01
#  5.600e+01 6.300e+01 1.350e+02 1.200e+02 1.160e+02 1.690e+02 6.600e+01
#  1.520e+02 9.600e+01 5.500e+01 9.800e+01 2.830e+02 1.370e+02 8.200e+01
# ...

# %%
'''
Filling null values in "SECURITY_DELAY" column with median value
'''
print(data_3["SECURITY_DELAY"].unique())                                                    # Checking for unique values
print("Count before handling null values : ",data_3["SECURITY_DELAY"].isnull().sum())       # Checking number of null values before handling null values
data_3["SECURITY_DELAY"].fillna(data_3["SECURITY_DELAY"].dropna().median(),inplace=True)    # Filling null values with default median value
print("Count after handling null values : ",data_3["SECURITY_DELAY"].isnull().sum())        # Checking number of null values after handling null values
# Out:
# [ nan   0.  46. 107.  11.  10.  30.  19.   6.   1.   2.   9.  17.  34.
#   35.  15.  28.  12.  27.  16.  99.  56.  20.  58.   7.  61.  13.   3.
#   14.  23.  21.   4.  54.  52.  53.  64.  24.  18.  50.  96.  62.  26.
#   32.  22.   5.  29.  39.  63.  45.  25.  80.  91.  59.  73.  31.   8.
#   40. 104.  36.  41. 237. 227.  68.  71.  47.  43.  55.  75.  37.  98.
#   57. 241.  92.  78.  42.  38.  97. 168. 141. 142.  33.  90.  51. 140.
#   69. 121. 190.  88. 123.  79. 204.  77. 158. 160. 215. 221.  49.  44.
#   94.  84.  65.  86. 102.  76.  81. 205. 101.  95.  85. 116.  48. 175.
#   67. 126.  66.  72. 138.  74. 103. 118. 154. 191.  60. 148. 214. 196.
#  135. 256. 110. 124. 203. 120. 164. 186.  93.  83.  70. 181. 122.  82.
#  108. 573. 128.  89. 106. 440. 127. 171. 129. 133. 149.  87. 364. 144.
#  105.]
# Count before handling null values :  4755640
# Count after handling null values :  0

# %%
'''
Filling null values in "AIRLINE_DELAY" column with median value
'''
print(data_3["AIRLINE_DELAY"].unique())                                                 # Checking for unique values
print("Count before handling null values : ",data_3["AIRLINE_DELAY"].isnull().sum())    # Checking number of null values before handling null values
data_3["AIRLINE_DELAY"].fillna(data_3["AIRLINE_DELAY"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["AIRLINE_DELAY"].isnull().sum())     # Checking number of null values after handling null values
# Out:
# [  nan    0.   15. ...  879. 1185. 1636.]
# Count before handling null values :  4755640
# Count after handling null values :  0

# %%
'''
Filling null values in "LATE_AIRCRAFT_DELAY" column with median value
'''
print(data_3["LATE_AIRCRAFT_DELAY"].unique())                                                       # Checking for unique values
print("Count before handling null values : ",data_3["LATE_AIRCRAFT_DELAY"].isnull().sum())          # Checking number of null values before handling null values
data_3["LATE_AIRCRAFT_DELAY"].fillna(data_3["LATE_AIRCRAFT_DELAY"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["LATE_AIRCRAFT_DELAY"].isnull().sum())           # Checking number of null values after handling null values
# Out:
# [      nan 0.000e+00 8.800e+01 3.100e+01 3.060e+02 3.000e+00 8.000e+00
#  7.000e+00 5.000e+00 1.200e+01 2.000e+01 1.100e+01 1.900e+01 2.900e+01
#  4.800e+01 2.500e+01 1.300e+01 7.500e+01 2.350e+02 1.000e+01 6.000e+00
#  6.200e+01 8.000e+01 1.600e+01 1.010e+02 3.700e+01 7.400e+01 1.400e+01
#  7.700e+01 6.300e+01 4.000e+01 1.840e+02 5.600e+01 1.400e+02 3.900e+01
#  2.600e+01 6.500e+01 4.670e+02 8.900e+01 1.000e+02 3.300e+01 4.000e+00
#  1.270e+02 1.160e+02 2.000e+00 9.000e+00 7.800e+01 2.100e+01 7.600e+01
#  1.800e+01 7.300e+01 5.900e+01 1.000e+00 1.210e+02 1.220e+02 4.200e+01
#  2.200e+01 2.300e+01 2.800e+01 1.740e+02 2.400e+01 1.280e+02 1.020e+02
#  6.700e+01 6.100e+01 2.640e+02 1.500e+01 3.500e+01 3.400e+01 4.300e+01
#  1.660e+02 4.100e+01 2.700e+01 5.700e+01 1.700e+01 7.100e+01 3.800e+01
#  3.600e+01 5.200e+01 3.000e+01 1.250e+02 5.100e+01 4.600e+01 1.230e+02
#  4.400e+01 8.200e+01 6.000e+01 1.180e+02 1.440e+02 4.500e+01 2.490e+02
# ...

# %%
'''
Filling null values in "WEATHER_DELAY" column with median value
'''
print(data_3["WEATHER_DELAY"].unique())                                                 # Checking for unique values
print("Count before handling null values : ",data_3["WEATHER_DELAY"].isnull().sum())    # Checking number of null values before handling null values
data_3["WEATHER_DELAY"].fillna(data_3["WEATHER_DELAY"].dropna().median(),inplace=True)  # Filling null values with default median value
print("Count after handling null values : ",data_3["WEATHER_DELAY"].isnull().sum())     # Checking number of null values after handling null values
# Out:
# [      nan 0.000e+00 1.020e+02 1.280e+02 2.130e+02 1.160e+02 1.110e+02
#  1.070e+02 5.400e+01 1.700e+01 1.310e+02 9.300e+01 1.600e+01 1.560e+02
#  4.000e+00 5.000e+01 2.800e+01 4.800e+01 5.500e+01 1.200e+02 2.400e+01
#  2.500e+01 4.100e+01 7.100e+01 1.900e+01 1.800e+01 7.800e+01 8.400e+01
#  1.500e+01 8.000e+00 9.000e+00 1.000e+00 6.100e+01 1.270e+02 1.400e+01
#  4.200e+01 1.370e+02 2.300e+01 3.600e+01 3.000e+00 5.000e+00 2.700e+01
#  1.250e+02 6.000e+00 1.200e+01 2.200e+01 6.200e+01 3.100e+01 7.000e+00
#  2.000e+00 2.000e+01 3.500e+01 3.300e+01 1.100e+01 6.800e+01 1.030e+02
#  7.500e+01 2.900e+01 3.000e+01 8.900e+01 8.100e+01 4.600e+01 5.100e+01
#  1.000e+01 2.100e+01 8.300e+01 6.600e+01 8.200e+01 1.040e+02 4.300e+01
#  1.500e+02 6.400e+01 4.500e+01 1.290e+02 1.340e+02 1.790e+02 7.200e+01
#  1.050e+02 5.700e+01 6.000e+01 5.600e+01 8.000e+01 6.700e+01 1.300e+01
#  1.580e+02 7.300e+01 1.620e+02 8.700e+01 3.900e+01 2.600e+01 3.400e+01
# ...

# %%
print(data_3.iloc[:,:].isnull().sum())      # To count number of null values in a (Data frame)data set "Test1_3.csv" file after handling data
# Out:
# YEAR                   0
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# FLIGHT_NUMBER          0
# TAIL_NUMBER            0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# TAXI_OUT               0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# TAXI_IN                0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# CANCELLATION_REASON    0
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0
# dtype: int64

# %%
'''
To visualize data
'''
import matplotlib.pyplot as plt     # Import matplotlib for ploting and visualize data
import seaborn as sns               # import seaborn as sns
sns.pairplot(data_2)                # visualize data by pairplot for data_2, (Test1_2.csv)
plt.show()                          # To show and viulize plot

# %%
sns.pairplot(data_3)    # visualize data by pairplot for data_3, (Test1_3.csv)
plt.show()              # To show and viulize plot

# %%
sns.heatmap(data_2.corr(),annot=True)       # visualize data and how much data is correlated by heatmap for data_2, (Test1_2.csv)
plt.show()                                  # To show and viulize plot
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_2912\348748834.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_2.corr(),annot=True)

# %%
plt.figure(figsize=[25,25])                     # To set figure size to visualize
sns.heatmap(data_3.iloc[:,:].corr(),annot=True) # visualize data and how much data is correlated by heatmap for data_3, (Test1_3.csv)
plt.show()                                      # To show and viulize plot
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_2912\732939813.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_3.iloc[:,:].corr(),annot=True)
